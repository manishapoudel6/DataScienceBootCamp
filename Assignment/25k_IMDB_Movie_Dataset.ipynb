# %%
import pandas as pd

# %%
path = '/content/25k IMDb movie Dataset.csv'
df = pd.read_csv(path)
df
# Out:
#                    movie title                    Run Time Rating User Rating  \
# 0            Top Gun: Maverick    $170,000,000 (estimated)    8.6        187K
# 1      Jurassic World Dominion          2 hours 27 minutes      6         56K
# 2                      Top Gun     $15,000,000 (estimated)    6.9        380K
# 3                    Lightyear                 $71,101,257    5.2         32K
# 4                   Spiderhead                not-released    5.4         23K
# ...                        ...                         ...    ...         ...
# 24397             Delicatessen  FRF 24,000,000 (estimated)    7.6         85K
# 24398                Bitch Ass                not-released    5.5          52
# 24399                 Bullwhip                not-released    5.1         398
# 24400             The Freshman           1 hour 42 minutes    6.4         20K
# 24401           Guys and Dolls      $5,500,000 (estimated)    7.1         18K
#
# ...

# %%
df.head(5) # Top 5 head of our dataset
# Out:
#                movie title                  Run Time Rating User Rating  \
# 0        Top Gun: Maverick  $170,000,000 (estimated)    8.6        187K
# 1  Jurassic World Dominion        2 hours 27 minutes      6         56K
# 2                  Top Gun   $15,000,000 (estimated)    6.9        380K
# 3                Lightyear               $71,101,257    5.2         32K
# 4               Spiderhead              not-released    5.4         23K
#
#                                 Generes  \
# 0                   ['Action', 'Drama']
# 1     ['Action', 'Adventure', 'Sci-Fi']
# 2                   ['Action', 'Drama']
# 3  ['Animation', 'Action', 'Adventure']
# 4          ['Action', 'Crime', 'Drama']
#
#                                             Overview  \
# 0  After more than thirty years of service as one...
# 1  Four years after the destruction of Isla Nubla...
# 2  As students at the United States Navy's elite ...
# 3  While spending years attempting to return home...
# ...

# %%
df.tail(5) # Last 5 rows of our dataset
# Out:
#           movie title                    Run Time Rating User Rating  \
# 24397    Delicatessen  FRF 24,000,000 (estimated)    7.6         85K
# 24398       Bitch Ass                not-released    5.5          52
# 24399        Bullwhip                not-released    5.1         398
# 24400    The Freshman           1 hour 42 minutes    6.4         20K
# 24401  Guys and Dolls      $5,500,000 (estimated)    7.1         18K
#
#                                Generes  \
# 24397              ['Comedy', 'Crime']
# 24398              ['Crime', 'Horror']
# 24399  ['Crime', 'Romance', 'Western']
# 24400              ['Comedy', 'Crime']
# 24401   ['Comedy', 'Crime', 'Musical']
#
#                                                 Overview  \
# 24397  Post-apocalyptic surrealist black comedy about...
# 24398  A gang initiation goes wrong when a group of f...
# 24399  In order to avoid the hangman's noose, a cowbo...
# 24400  An N.Y.C. film school student accepts a job wi...
# ...

# %%
df.shape
# Out:
# (24402, 12)

# %%
df.describe() # getting overall #statistics about our dataset
# Out:
#        movie title      Run Time     Rating User Rating    Generes Overview  \
# count        24402         24402      24402       24402      24402    24158
# unique       23922          1556         91        1684        746    23957
# top           Rage  not-released  no-rating           0  ['Drama']     none
# freq             4          8475       1740        1740        943      142
#
#        Plot Kyeword                         Director  \
# count         24402                            24402
# unique        21546                            11604
# top              []  See company contact information
# freq           1696                              142
#
#                                      Top 5 Casts      Writer   year  \
# count                                      24402       24402  23624
# unique                                     24211       15562    250
# top     ['See producer', 'See preliminary cast']  See writer  -2022
# ...

# %%
df.columns
# Out:
# Index(['movie title', 'Run Time', 'Rating', 'User Rating', 'Generes',
#        'Overview', 'Plot Kyeword', 'Director', 'Top 5 Casts', 'Writer', 'year',
#        'path'],
#       dtype='object')

# %%
print('Any Missing Values?', df.isnull().values.any())
# Out:
# Any Missing Values? True

# %%
df.isnull().sum()
# Out:
# movie title       0
# Run Time          0
# Rating            0
# User Rating       0
# Generes           0
# Overview        244
# Plot Kyeword      0
# Director          0
# Top 5 Casts       0
# Writer            0
# year            778
# path              0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull()) # These map showing there is null value in two columns
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (24402, 12)

# %%
df['Overview'].fillna(0, inplace=True) # Filling the null value of 'Overview' column.

# %%
df['year'].fillna(method='bfill', inplace = True) # filling the null value from 'year' column.

# %%
df.isnull().sum()
# Out:
# movie title     0
# Run Time        0
# Rating          0
# User Rating     0
# Generes         0
# Overview        0
# Plot Kyeword    0
# Director        0
# Top 5 Casts     0
# Writer          0
# year            0
# path            0
# dtype: int64

# %%
# Checking for Duplicte data

dup_data = df.duplicated().any()

print('Are there any duplicate values?', dup_data)
# Out:
# Are there any duplicate values? False

# %%
df.iloc[6] #extracting the value from 7th row
# Out:
# movie title                                           Interceptor
# Run Time                                             not-released
# Rating                                                        4.4
# User Rating                                                   17K
# Generes                          ['Action', 'Adventure', 'Drama']
# Overview        One Army captain must use her years of tactica...
# Plot Kyeword    ['violence', 'gun', 'handgun', 'gun fight', 'o...
# Director                                           Matthew Reilly
# Top 5 Casts     ['Stuart Beattie', 'Elsa Pataky', 'Luke Bracey...
# Writer                                             Matthew Reilly
# year                                                        -2022
# path                                           /title/tt14174940/
# Name: 6, dtype: object

# %%
df.rename(columns={'Generes': 'genre'}, inplace=True)

# %%
df.rename(columns={'Run Time': 'Run_time'}, inplace = True)

# %%
df.rename(columns={'User Rating': 'User_Rating'}, inplace = True)

# %%
df.rename(columns={'movie title': 'movie_title'}, inplace = True)

# %%
df.head(2)
# Out:
#                movie_title                  Run_time Rating User_Rating  \
# 0        Top Gun: Maverick  $170,000,000 (estimated)    8.6        187K
# 1  Jurassic World Dominion        2 hours 27 minutes      6         56K
#
#                                genre  \
# 0                ['Action', 'Drama']
# 1  ['Action', 'Adventure', 'Sci-Fi']
#
#                                             Overview  \
# 0  After more than thirty years of service as one...
# 1  Four years after the destruction of Isla Nubla...
#
#                                         Plot Kyeword         Director  \
# 0  ['fighter jet', 'sequel', 'u.s. navy', 'fighte...  Joseph Kosinski
# 1  ['dinosaur', 'jurassic park', 'tyrannosaurus r...  Colin Trevorrow
#
#                                          Top 5 Casts            Writer   year  \
# 0  ['Jack Epps Jr.', 'Peter Craig', 'Tom Cruise',...          Jim Cash  -2022
# 1  ['Colin Trevorrow', 'Derek Connolly', 'Chris P...  Emily Carmichael  -2022
#
# ...

# %%
# Displaying the runtime  having unique values.

df['Run_time'].unique()
# Out:
# array(['$170,000,000 (estimated)', '2 hours 27 minutes',
#        '$15,000,000 (estimated)', ..., '$32,886,940', '$28,061,343',
#        'FRF\xa024,000,000 (estimated)'], dtype=object)

# %%
# Finding out which year has a highest average rating

df.groupby('year')['Rating'].value_counts(ascending = False)
# Out:
# year   Rating
# (I)    no-rating    58
#        6.8           3
#        4.7           1
#        6             1
#        7             1
#                     ..
# -2025  no-rating    14
#        3.6           1
# -2026  no-rating     3
# -2027  no-rating     5
# -2028  no-rating     2
# Name: Rating, Length: 5208, dtype: int64

# %%
df.head(1)
# Out:
#          movie_title                  Run_time Rating User_Rating  \
# 0  Top Gun: Maverick  $170,000,000 (estimated)    8.6        187K
#
#                  genre                                           Overview  \
# 0  ['Action', 'Drama']  After more than thirty years of service as one...
#
#                                         Plot Kyeword         Director  \
# 0  ['fighter jet', 'sequel', 'u.s. navy', 'fighte...  Joseph Kosinski
#
#                                          Top 5 Casts    Writer   year  \
# 0  ['Jack Epps Jr.', 'Peter Craig', 'Tom Cruise',...  Jim Cash  -2022
#
#                 path
# 0  /title/tt1745960/

# %%
df['Director'] = df['Director'].str.lower()

# %%
df
# Out:
#                    movie_title                    Run_time Rating User_Rating  \
# 0            Top Gun: Maverick    $170,000,000 (estimated)    8.6        187K
# 1      Jurassic World Dominion          2 hours 27 minutes      6         56K
# 2                      Top Gun     $15,000,000 (estimated)    6.9        380K
# 3                    Lightyear                 $71,101,257    5.2         32K
# 4                   Spiderhead                not-released    5.4         23K
# ...                        ...                         ...    ...         ...
# 24397             Delicatessen  FRF 24,000,000 (estimated)    7.6         85K
# 24398                Bitch Ass                not-released    5.5          52
# 24399                 Bullwhip                not-released    5.1         398
# 24400             The Freshman           1 hour 42 minutes    6.4         20K
# 24401           Guys and Dolls      $5,500,000 (estimated)    7.1         18K
#
# ...

# %%
df['year']=df['year'].str.replace('-','') #Removing - fromt the front of the each year

# %%
df.head(40)
# Out:
#                                     movie_title                  Run_time  \
# 0                             Top Gun: Maverick  $170,000,000 (estimated)
# 1                       Jurassic World Dominion        2 hours 27 minutes
# 2                                       Top Gun   $15,000,000 (estimated)
# 3                                     Lightyear               $71,101,257
# 4                                    Spiderhead              not-released
# 5             Everything Everywhere All at Once        2 hours 19 minutes
# 6                                   Interceptor              not-released
# 7                                   Interceptor         1 hour 30 minutes
# 8                                    Black Adam              not-released
# 9                                  The Northman   $60,000,000 (estimated)
# 10                       Thor: Love and Thunder              not-released
# 11  Fantastic Beasts: The Secrets of Dumbledore        2 hours 22 minutes
# ...

# %%
import pandas as pd

df['year'] = df['year'].str.replace('\s*\(I\)', '', regex=True) #First I removed (I)

# %%
df['year'] = df['year'].str.replace(r'\(|\)', '', regex=True) #Second I removed ()

# %%
df.head(40)
# Out:
#                                     movie_title                  Run_time  \
# 0                             Top Gun: Maverick  $170,000,000 (estimated)
# 1                       Jurassic World Dominion        2 hours 27 minutes
# 2                                       Top Gun   $15,000,000 (estimated)
# 3                                     Lightyear               $71,101,257
# 4                                    Spiderhead              not-released
# 5             Everything Everywhere All at Once        2 hours 19 minutes
# 6                                   Interceptor              not-released
# 7                                   Interceptor         1 hour 30 minutes
# 8                                    Black Adam              not-released
# 9                                  The Northman   $60,000,000 (estimated)
# 10                       Thor: Love and Thunder              not-released
# 11  Fantastic Beasts: The Secrets of Dumbledore        2 hours 22 minutes
# ...

# %%
df['genre'] = df['genre'].str.replace(r'\[|\]|\'', '', regex=True)

# %%
df.head(40)

# %%
filtered_df = df[df['genre'] == 'Romance'] # Counting number of Romance movie
filtered_df['genre'].count()
# Out:
# 22

# %%
df['genre'].value_counts()
# Out:
# Drama                        943
# Action, Crime, Drama         867
# Crime, Drama, Thriller       609
# Comedy, Drama, Romance       608
# Crime, Drama                 550
#                             ...
# Drama, Romance, Crime          1
# Drama, Crime, Mystery          1
# Family, Adventure, Comedy      1
# Crime, Mystery, Horror         1
# Crime, Romance, Western        1
# Name: genre, Length: 746, dtype: int64

# %%
directors = {} #Counting how many movies these each director has made.
def per_director(Name):
    directors[Name] = len(df[df['Director'] == Name])

for value in df['Director'].values:
    per_director(value)

index_labels = ['movies_count']
director = pd.DataFrame(directors, index=index_labels)
director
# Out:
#               joseph kosinski  colin trevorrow  tony scott  angus maclane  \
# movies_count                4                4          15              1
#
#               dan kwan  matthew reilly  konstantin maksimov  \
# movies_count         2               1                    1
#
#               jaume collet-serra  robert eggers  taika waititi  ...  \
# movies_count                  10              2             10  ...
#
#               pat holden  lucian pintilie  will addison  sydney freeland  \
# movies_count           1                1             1                1
#
#               wesley strick  robert bierman  susan stroman  scott alexander  \
# movies_count              1               1              1                1
#
#               edward killy  bill posley
# movies_count             1            1
#
# [1 rows x 11604 columns]
