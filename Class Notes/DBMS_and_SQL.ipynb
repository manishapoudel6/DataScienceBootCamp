# %% [markdown]
# #**Wednesday Sept 06, 2023**

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df_chipotle = pd.read_csv(url, sep='\t')
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_chipotle[df_chipotle.item_name == 'Chips and Fresh Tomato Salsa']
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %%
df_chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df_chipotle.item_price
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df_chipotle['item_price']= df_chipotle['item_price'].str.replace('$',' ')
df_chipotle
# Out:
# <ipython-input-9-3d392a8e5035>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_chipotle['item_price']= df_chipotle['item_price'].str.replace('$',' ')
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# ...

# %%
df_chipotle['item_price'] = df_chipotle['item_price'].astype(float)

# %%
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_chipotle[df_chipotle.item_price > 10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
df_chipotle[df_chipotle.item_name == 'Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df_chipotle[df_chipotle.item_name.str.contains('Chicken',case = False)]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...        8.75
# ...

# %%
df_chipotle.filter(regex='e$', axis=1)
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
df_chipotle.filter([df_chipotle.item_name.str.contains('Chicken',case = False)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-95117e37c88d> in <cell line: 1>()
# ----> 1 df_chipotle.filter([df_chipotle.item_name.str.contains('Chicken',case = False)])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in filter(self, items, like, regex, axis)
#    5452         if items is not None:
#    5453             name = self._get_axis_name(axis)
# -> 5454             return self.reindex(**{name: [r for r in items if r in labels]})
#    5455         elif like:
#    5456
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in <listcomp>(.0)
#    5452         if items is not None:
#    5453             name = self._get_axis_name(axis)
# -> 5454             return self.reindex(**{name: [r for r in items if r in labels]})
#    5455         elif like:
#    5456
#
# ...

# %%
df_chipotle[df_chipotle.item_price >= 20]
# Out:
#       order_id  quantity                     item_name  \
# 135         60         2            Chicken Salad Bowl
# 213         94         2            Chicken Salad Bowl
# 281        123         2              Steak Salad Bowl
# 353        152         2                 Steak Burrito
# 409        178         3                  Chicken Bowl
# 445        193         3                          Bowl
# 506        212         2                 Carnitas Bowl
# 549        229         2                 Steak Burrito
# 591        243         2            Chicken Salad Bowl
# 613        253         2              Steak Salad Bowl
# 633        261         2            Chicken Salad Bowl
# 816        337         2            Chicken Salad Bowl
# 864        357         2            Chicken Salad Bowl
# 1110       459         2            Chicken Salad Bowl
# 1254       511         4               Chicken Burrito
# 1255       511         3                 Steak Burrito
# ...

# %%
df_chipotle.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_chipotle[(df_chipotle['item_name'].isin (['Chicken Bowl']))]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df_chipotle.sum()
# Out:
# <ipython-input-23-f17abc7c0b8e>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_chipotle.sum()
# order_id                                                4285772
# quantity                                                   4972
# item_name     Chips and Fresh Tomato SalsaIzzeNantucket Nect...
# item_price                                             34500.16
# dtype: object

# %%
df_chipotle.max()
# Out:
# <ipython-input-24-e7770f61c091>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_chipotle.max()
# order_id                   1834
# quantity                     15
# item_name     Veggie Soft Tacos
# item_price                44.25
# dtype: object

# %%
df_chipotle.isnull().sum(axis = 0)
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df_chipotle.isnull()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]

# %%
df_chipotle.shape
# Out:
# (4622, 5)

# %%
df_chipotle.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %%
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df_users = pd.read_csv(url, sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df_users.occupation.unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
df_users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
df_users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
df_users.groupby('occupation').sum()
# Out:
# <ipython-input-33-ae37452f49f5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby('occupation').sum()
#                user_id   age
# occupation
# administrator    34045  3061
# artist           12653   879
# doctor            3736   305
# educator         44356  3991
# engineer         30574  2438
# entertainment     7164   526
# executive        13514  1239
# healthcare        8023   665
# homemaker         3101   228
# lawyer            4309   441
# librarian        24816  2040
# marketing        11383   978
# none              3318   239
# other            56987  3625
# programmer       28745  2186
# retired           7220   883
# salesman          5939   428
# scientist        14419  1102
# student          95051  4328
# technician       13436   895
# ...

# %%
df_users.groupby('occupation').count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
df_users.groupby('occupation').count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       79   79      79        79
# artist              28   28      28        28
# doctor               7    7       7         7
# educator            95   95      95        95
# engineer            67   67      67        67
# entertainment       18   18      18        18
# executive           32   32      32        32
# healthcare          16   16      16        16
# homemaker            7    7       7         7
# lawyer              12   12      12        12
# librarian           51   51      51        51
# marketing           26   26      26        26
# none                 9    9       9         9
# other              105  105     105       105
# programmer          66   66      66        66
# retired             14   14      14        14
# salesman            12   12      12        12
# scientist           31   31      31        31
# student            196  196     196       196
# ...

# %%
df_users.groupby('occupation').first() #print the first entries
# Out:
#                user_id  age gender zip_code
# occupation
# administrator        7   57      M    91344
# artist              23   30      F    48197
# doctor             138   46      M    53211
# educator            13   47      M    29206
# engineer            25   39      M    55107
# entertainment       16   21      M    10309
# executive            6   42      M    98101
# healthcare          60   50      M    06472
# homemaker           20   42      F    95660
# lawyer              10   53      M    90703
# librarian           19   40      M    02138
# marketing           46   27      F    46538
# none                57   16      M    84010
# other                2   53      F    94043
# programmer          17   30      M    06355
# retired            106   61      M    55125
# salesman           112   30      M    60613
# scientist           14   45      M    55106
# student              9   29      M    01002
# technician           1   24      M    85711
# ...

# %%
df_users.groupby('occupation').std()
# Out:
# <ipython-input-37-130d002352f9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_users.groupby('occupation').std()
#                   user_id        age
# occupation
# administrator  281.302962  11.123397
# artist         322.963860   8.668116
# doctor         330.491913  12.501428
# educator       250.727201  10.413264
# engineer       261.663697  11.199236
# entertainment  295.854098  10.056052
# executive      287.533049  10.608075
# healthcare     261.480393  11.313524
# homemaker      345.112059  10.737119
# lawyer         251.926562  10.830303
# librarian      284.491207  11.023611
# marketing      283.864900   9.474500
# none           258.455025  13.757826
# other          274.932938  10.738227
# programmer     263.086603   9.624512
# retired        235.690615   5.757461
# ...

# %%
df_users.groupby('occupation').age.median()
# Out:
# occupation
# administrator    37.0
# artist           30.0
# doctor           45.0
# educator         42.0
# engineer         36.0
# entertainment    25.0
# executive        38.5
# healthcare       44.5
# homemaker        32.0
# lawyer           34.0
# librarian        39.0
# marketing        36.0
# none             26.0
# other            32.0
# programmer       30.0
# retired          63.0
# salesman         34.0
# scientist        37.0
# student          21.0
# technician       30.0
# writer           36.0
# Name: age, dtype: float64

# %%
df_users.groupby('occupation').user_id.median()
# Out:
# occupation
# administrator    436.0
# artist           421.5
# doctor           427.0
# educator         485.0
# engineer         467.0
# entertainment    381.0
# executive        346.0
# healthcare       563.5
# homemaker        362.0
# lawyer           352.0
# librarian        527.0
# marketing        469.5
# none             289.0
# other            597.0
# programmer       417.5
# retired          522.5
# salesman         450.0
# scientist        483.0
# student          474.5
# technician       488.0
# writer           504.0
# Name: user_id, dtype: float64

# %%
df_users.groupby('occupation').agg([np.mean,np.median])
# Out:
# <ipython-input-40-fd6cfc468d8d>:1: FutureWarning: ['gender', 'zip_code'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_users.groupby('occupation').agg([np.mean,np.median])
#                   user_id               age
#                      mean median       mean median
# occupation
# administrator  430.949367  436.0  38.746835   37.0
# artist         451.892857  421.5  31.392857   30.0
# doctor         533.714286  427.0  43.571429   45.0
# educator       466.905263  485.0  42.010526   42.0
# engineer       456.328358  467.0  36.388060   36.0
# entertainment  398.000000  381.0  29.222222   25.0
# executive      422.312500  346.0  38.718750   38.5
# healthcare     501.437500  563.5  41.562500   44.5
# homemaker      443.000000  362.0  32.571429   32.0
# lawyer         359.083333  352.0  36.750000   34.0
# librarian      486.588235  527.0  40.000000   39.0
# ...

# %%
df_users.groupby(['occupation','gender']).count()
# Out:
#                       user_id  age  zip_code
# occupation    gender
# administrator F            36   36        36
#               M            43   43        43
# artist        F            13   13        13
#               M            15   15        15
# doctor        M             7    7         7
# educator      F            26   26        26
#               M            69   69        69
# engineer      F             2    2         2
#               M            65   65        65
# entertainment F             2    2         2
#               M            16   16        16
# executive     F             3    3         3
#               M            29   29        29
# healthcare    F            11   11        11
#               M             5    5         5
# homemaker     F             6    6         6
#               M             1    1         1
# lawyer        F             2    2         2
#               M            10   10        10
# ...

# %%
df_users.query("occupation == 'homemaker'").groupby(['occupation','gender']).count()
# Out:
#                    user_id  age  zip_code
# occupation gender
# homemaker  F             6    6         6
#            M             1    1         1

# %%
df_homemaker = df_users[df_users['occupation'] == 'homemaker'].groupby('gender').count()

df_homemaker
# Out:
#         user_id  age  occupation  zip_code
# gender
# F             6    6           6         6
# M             1    1           1         1

# %%
df_users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %% [markdown]
# #**Thursday Sept 07 2023**

# %%
df_users.groupby('age').count()
# Out:
#      user_id  gender  occupation  zip_code
# age
# 7          1       1           1         1
# 10         1       1           1         1
# 11         1       1           1         1
# 13         5       5           5         5
# 14         3       3           3         3
# ..       ...     ...         ...       ...
# 66         1       1           1         1
# 68         2       2           2         2
# 69         2       2           2         2
# 70         3       3           3         3
# 73         1       1           1         1
#
# [61 rows x 4 columns]

# %%
df_users[df_users['age'] >= 18].groupby(['age']).size().reset_index(name='count')
# Out:
#     age  count
# 0    18     18
# 1    19     23
# 2    20     32
# 3    21     27
# 4    22     37
# 5    23     28
# 6    24     33
# 7    25     38
# 8    26     34
# 9    27     35
# 10   28     36
# 11   29     32
# 12   30     39
# 13   31     25
# 14   32     28
# 15   33     26
# 16   34     17
# 17   35     27
# 18   36     21
# 19   37     19
# 20   38     17
# 21   39     22
# 22   40     21
# 23   41     10
# 24   42     21
# 25   43     13
# 26   44     23
# 27   45     15
# 28   46     12
# 29   47     14
# 30   48     20
# 31   49     19
# 32   50     20
# 33   51     20
# 34   52      6
# 35   53     12
# 36   54      4
# 37   55     11
# 38   56      6
# 39   57      9
# 40   58      3
# 41   59      3
# 42   60      9
# 43   61      3
# 44   62      2
# 45   63      3
# 46   64      2
# 47   65      3
# 48   66      1
# 49   68      2
# 50   69      2
# 51   70      3
# 52   73      1

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
regiment = pd.DataFrame(raw_data, columns = raw_data.keys())

# %%
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
regiment.groupby('regiment').company.count()
# Out:
# regiment
# Dragoons      4
# Nighthawks    4
# Scouts        4
# Name: company, dtype: int64

# %%
regiment[regiment['regiment']=='Scouts'].groupby('regiment').count()
# Out:
#           company  name  preTestScore  postTestScore
# regiment
# Scouts          4     4             4              4

# %%
regiment[regiment['name'] == 'Ali'].groupby('name').count()
# Out:
#       regiment  company  preTestScore  postTestScore
# name
# Ali          2        2             2              2

# %%
regiment[regiment['preTestScore'] >= 15].groupby('preTestScore').count()
# Out:
#               regiment  company  name  postTestScore
# preTestScore
# 24                   2        2     2              2
# 31                   2        2     2              2

# %%
regiment[regiment['company'].isin(['1st','2nd'])].groupby('company').count()
# Out:
#          regiment  name  preTestScore  postTestScore
# company
# 1st             6     6             6              6
# 2nd             6     6             6              6

# %%
regiment[regiment['postTestScore'] <= 50].groupby('postTestScore').count()
# Out:
#                regiment  company  name  preTestScore
# postTestScore
# 25                    2        2     2             2

# %%
regiment.groupby(['company', 'regiment']).size()
# Out:
# company  regiment
# 1st      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# 2nd      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# dtype: int64

# %%
regiment.groupby(['regiment', 'company']).mean()
# Out:
# <ipython-input-73-5808efbeaedb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   regiment.groupby(['regiment', 'company']).mean()
#                     preTestScore  postTestScore
# regiment   company
# Dragoons   1st               3.5           47.5
#            2nd              27.5           75.5
# Nighthawks 1st              14.0           59.5
#            2nd              16.5           59.5
# Scouts     1st               2.5           66.0
#            2nd               2.5           66.0

# %%
regiment.groupby(['regiment', 'company']).preTestScore.mean().unstack()
# Out:
# company      1st   2nd
# regiment
# Dragoons     3.5  27.5
# Nighthawks  14.0  16.5
# Scouts       2.5   2.5

# %%
regiment.groupby(['regiment', 'company']).preTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %%
regiment.groupby('company').preTestScore.mean()
# Out:
# company
# 1st     6.666667
# 2nd    15.500000
# Name: preTestScore, dtype: float64

# %%
regiment.groupby('company').describe()
# Out:
#         preTestScore                                                      \
#                count       mean        std  min   25%   50%    75%   max
# company
# 1st              6.0   6.666667   8.524475  2.0  3.00   3.5   4.00  24.0
# 2nd              6.0  15.500000  14.652645  2.0  2.25  13.5  29.25  31.0
#
#         postTestScore
#                 count       mean        std   min    25%   50%   75%   max
# company
# 1st               6.0  57.666667  27.485754  25.0  34.25  66.0  70.0  94.0
# 2nd               6.0  67.000000  14.057027  57.0  58.25  62.0  68.0  94.0

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
df_uscrime = pd.read_csv(url)
df_uscrime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
df_uscrime.describe()
# Out:
#              Year    Population         Total       Violent      Property  \
# count    55.00000  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1987.00000  2.461556e+08  1.060315e+07  1.188806e+06  9.412499e+06
# std      16.02082  4.166216e+07  3.175931e+06  4.597107e+05  2.738512e+06
# min    1960.00000  1.793232e+08  3.384200e+06  2.884600e+05  3.095700e+06
# 25%    1973.50000  2.106215e+08  9.096958e+06  9.253150e+05  8.060014e+06
# 50%    1987.00000  2.422829e+08  1.140151e+07  1.322390e+06  1.018259e+07
# 75%    2000.50000  2.833697e+08  1.308449e+07  1.432762e+06  1.160509e+07
# max    2014.00000  3.188571e+08  1.487290e+07  1.932270e+06  1.296110e+07
#
#              Murder  Forcible_Rape        Robbery  Aggravated_assault  \
# count     55.000000      55.000000      55.000000        5.500000e+01
# mean   17317.236364   72714.800000  416449.890909        6.811818e+05
# std     4267.442664   28278.006893  150506.403782        2.960255e+05
# ...

# %%
df_uscrime.count()
# Out:
# Year                  55
# Population            55
# Total                 55
# Violent               55
# Property              55
# Murder                55
# Forcible_Rape         55
# Robbery               55
# Aggravated_assault    55
# Burglary              55
# Larceny_Theft         55
# Vehicle_Theft         55
# dtype: int64

# %%
df_uscrime.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
df_uscrime.min()
# Out:
# Year                       1960
# Population            179323175
# Total                   3384200
# Violent                  288460
# Property                3095700
# Murder                     8530
# Forcible_Rape             17190
# Robbery                  106670
# Aggravated_assault       154320
# Burglary                 912100
# Larceny_Theft           1855400
# Vehicle_Theft            328200
# dtype: int64

# %%
df_uscrime.max()
# Out:
# Year                       2014
# Population            318857056
# Total                  14872900
# Violent                 1932270
# Property               12961100
# Murder                    24700
# Forcible_Rape            109060
# Robbery                  687730
# Aggravated_assault      1135610
# Burglary                3795200
# Larceny_Theft           8142200
# Vehicle_Theft           1661700
# dtype: int64

# %%
df_uscrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
df_uscrime.mean()
# Out:
# Year                  1.987000e+03
# Population            2.461556e+08
# Total                 1.060315e+07
# Violent               1.188806e+06
# Property              9.412499e+06
# Murder                1.731724e+04
# Forcible_Rape         7.271480e+04
# Robbery               4.164499e+05
# Aggravated_assault    6.811818e+05
# Burglary              2.424017e+06
# Larceny_Theft         5.959947e+06
# Vehicle_Theft         1.028614e+06
# dtype: float64

# %%
df_uscrime.std()
# Out:
# Year                  1.602082e+01
# Population            4.166216e+07
# Total                 3.175931e+06
# Violent               4.597107e+05
# Property              2.738512e+06
# Murder                4.267443e+03
# Forcible_Rape         2.827801e+04
# Robbery               1.505064e+05
# Aggravated_assault    2.960255e+05
# Burglary              7.259004e+05
# Larceny_Theft         1.846401e+06
# Vehicle_Theft         3.455693e+05
# dtype: float64

# %%
df_uscrime.shape
# Out:
# (55, 12)

# %%
df_uscrime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df_uscrime.tail()
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
# 53  2013   316497531   9850445  1199684   8650761   14319          82109
# 54  2014   318857056   9475816  1197987   8277829   14249          84041
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 50   369089              781844   2168457        6204601         739565
# 51   354772              752423   2185140        6151095         716508
# 52   355051              762009   2109932        6168874         723186
# 53   345095              726575   1931835        6018632         700294
# 54   325802              741291   1729806        5858496         689527

# %%
df_uscrime.iloc[3:7,3:6]
# Out:
#    Violent  Property  Murder
# 3   316970   3792500    8640
# 4   364220   4200400    9360
# 5   387390   4352000    9960
# 6   430180   4793300   11040

# %%
df_uscrime.loc[3:4,'Violent':'Violent']
# Out:
#    Violent
# 3   316970
# 4   364220

# %%
df_uscrime.iloc[:7,:]
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
# 5  1965   193526000  4739400   387390   4352000    9960          23410
# 6  1966   195576000  5223500   430180   4793300   11040          25820
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# ...

# %%
df_uscrime[df_uscrime['Year'].isin([1963])].groupby('Robbery').size()
# Out:
# Robbery
# 116470    1
# dtype: int64

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

# %%
data_new = pd.concat([data1, data2])
data_new
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_row = pd.concat([data1, data2], axis=0) #concatinate by row
data_new_row
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data_new_col = pd.concat([data1, data2], axis=1)#concatibate by column
data_new_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
pd.merge(data_new, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15
